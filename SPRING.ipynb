# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("WFT_SUV_City1_R1_Sample.csv")

# %%
df.head()
# Out:
#    sr         t  T2@speed_ms.RN_1  T1@CS_RR.RN_1  T1@CS_RL.RN_1  \
# 0   1  22.00000               0.0      -1.429734      11.313050
# 1   2  22.00195               0.0      -1.622248      11.313050
# 2   3  22.00391               0.0      -1.044706      11.121500
# 3   4  22.00586               0.0      -0.082135      10.738410
# 4   5  22.00781               0.0       1.072950       9.972214
#
#    T1@ARB_R.RN_1  T1@AXLE_RR_Z.RN_1  T1@AXLE_RL_Z.RN_1  T1@Mz4.RN_1  \
# 0       3.460734          -2.661185          -3.110147        12.00
# 1       3.460734          -2.661185          -3.110147        12.25
# 2       3.617605          -2.816207          -3.265722        10.75
# 3       3.617605          -2.816207          -3.421296        11.25
# 4       3.617605          -2.971230          -3.576871        12.00
#
#    T1@My4.RN_1      ...       T1@My3.RN_1  T1@Mx3.RN_1  T1@Fz3.RN_1  \
# 0        13.25      ...              8.75        64.50         6218
# ...

# %%
newdf = df[df.columns[0:5]]#df[['T2@speed_ms.RN_1','T1@CS_RR.RN_1', 'T1@CS_RL.RN_1']] + df[[1]]

# %%
newdf.index.get_values()
# Out:
# array([   0,    1,    2, ..., 3070, 3071, 3072], dtype=int64)

# %%
rol = newdf[['t','T2@speed_ms.RN_1','T1@CS_RR.RN_1','T1@CS_RL.RN_1']]

# %%
rol.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
